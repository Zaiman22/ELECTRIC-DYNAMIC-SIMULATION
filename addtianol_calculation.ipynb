# %% [markdown]
# # Additional Calculation
# This is additioncal calculation for the simulation. This is also a step for migrating into a python enviroment

# %% [markdown]
# #### BLDC function for mitsuba 1048 with 24V supply
# ![image.png](attachment:image.png)
# for
